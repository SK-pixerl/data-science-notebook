# %% [markdown]
# # SK

# %% [markdown]
# ## Introduction
# This notebook provides an overview of essential concepts in data science, including languages, libraries, tools, and basic computations using Python.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Description                           |
# |-----------------|---------------------------------------|
# | Jupyter Notebook| Interactive coding environment        |
# | RStudio         | IDE for R programming                 |
# | Apache Spark    | Big data processing engine            |
# | TensorFlow      | Deep learning framework               |
# | Tableau         | Data visualization platform           |

# %% [markdown]
# ## Arithmetic Expressions in Python
# Below are examples of basic arithmetic operations such as addition and multiplication.

# %%
# This will perform multiplication and addition
result = (3 * 4) + 5
print("Result of (3 * 4) + 5 is:", result)

# %%
# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
print("200 minutes is equal to", hours, "hours")

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - Introduce commonly used libraries in Data Science
# - Demonstrate arithmetic operations in Python
# - Convert units using Python code

# %% [markdown]
# ## Author
# Sanjeev Kumar
